# %%
import os
import re
import pandas as pd

# %%
def extract_paren_index(fname: str) -> int:
    """
    Get the number inside parentheses at end of stem, e.g. '... (3).png' -> 3
    If none, return a large number so it sorts last.
    """
    stem, _ = os.path.splitext(fname)
    m = re.search(r"\((\d+)\)\s*$", stem)
    if m:
        return int(m.group(1))
    return 999999

# %%
BASE_DIR = "/Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects"
IMAGE_EXTS = (".png", ".jpg", ".jpeg", ".tif", ".tiff", ".gif")

rows = []


# Folders to ignore at the top level of objects/
IGNORE_FOLDERS = {"small", "thumb", "thumbs", ".DS_Store"}

for folder in sorted(os.listdir(BASE_DIR)):
    if folder in IGNORE_FOLDERS:
        continue

    folder_path = os.path.join(BASE_DIR, folder)
    if not os.path.isdir(folder_path):
        continue

    # Only image files in this article folder
    files = [
        f for f in os.listdir(folder_path)
        if f.lower().endswith(IMAGE_EXTS)
    ]

    if not files:
        continue

    # Sort files by (n) index so (1) comes before (2), etc.
    files.sort(key=extract_paren_index)

    rename_info = []

    for idx, fname in enumerate(files, start=1):
        stem, ext = os.path.splitext(fname)
        # Remove trailing " (n)" from stem
        base_stem = re.sub(r"\s*\(\d+\)\s*$", "", stem)
        # New filename with underscore index
        new_name = f"{base_stem}_{idx}{ext}"

        old_path = os.path.join(folder_path, fname)
        new_path = os.path.join(folder_path, new_name)

        if old_path != new_path:
            print(f"Renaming: {old_path} -> {new_path}")
            os.rename(old_path, new_path)

        rename_info.append((idx, new_name))

    # Use folder name as the "article id"
    article_id = folder
    parent_id = f"{article_id}_Original"

    # First image is used on the parent row
    first_idx, first_new_name = rename_info[0]

    # ---- Parent (compound object) row ----
    rows.append({
        "object_id": parent_id,
        "article_id": article_id,
        "image_display_template": "compound_object",
        "image_parent_id": "",
        "image_file": first_new_name,
        "image_object_location": f"{BASE_DIR}/{folder}/{first_new_name}",
    })

    # ---- Child image rows ----
    for idx, new_name in rename_info:
        child_id = f"{article_id}_img{idx}"
        rows.append({
            "object_id": child_id,
            "article_id": article_id,
            "image_display_template": "image",
            "image_parent_id": parent_id,
            "image_file": new_name,
            "image_object_location": f"{BASE_DIR}/{folder}/{new_name}",
        })

# Build DataFrame and save
df = pd.DataFrame(rows, columns=[
    "object_id",
    "article_id",
    "image_display_template",
    "image_parent_id",
    "image_file",
    "image_object_location",
])

df.to_csv("image_metadata_test.csv", index=False)
print("Wrote image metadata to image_metadata_test.csv")
# Out:
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_8.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_8_1.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_5.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_5_2.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_4.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_4_3.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_6.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_6_4.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_7.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_7_5.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_3.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_3_6.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_2.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_2_7.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_1.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1853/AlbanyEveningJournal1853_DigSur_1_8.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_3.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_3_1.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_2.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_2_2.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_1.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_1_3.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_5.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_5_4.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_4.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlbanyEveningJournal1879/AlbanyEveningJournal1879_DigSur_4_5.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_5.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_5_1.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_4.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_4_2.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_1.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_1_3.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_3.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_3_4.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_2.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlexandriaGazette1889/AlexandriaGazette1889_DigSur_2_5.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_7.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_7_1.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_6.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_6_2.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_4.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_4_3.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_5.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_5_4.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_1.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_1_5.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_2.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_2_6.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_3.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_3_7.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_10.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_10_8.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_11.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_11_9.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_13.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_13_10.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_12.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_12_11.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_8.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_8_12.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_9.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_9_13.png
# Renaming: /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_14.png -> /Users/owenmonroe/Desktop/GitHub/lonewoman_cb_test/objects/AlleganyCountyRepublican1901/AlleganyCountyRepublican1901_DigSur_14_14.png
# Wrote image metadata to image_metadata_test.csv
